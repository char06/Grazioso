# %%
import pymongo
import pandas as pd
import json

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
df = pd.read_csv("/users/carlosaguirre/desktop/Austin_Animal_Center_Outcomes.csv")

# %%
df.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# ...

# %%
df.tail()
# Out:
#        Animal ID        Name                DateTime MonthYear Date of Birth  \
# 148963   A859974  *Lady Gaga  08/16/2022 11:42:00 AM  Aug 2022    06/21/2012
# 148964   A856973      *Suede  06/11/2022 03:39:00 PM  Jun 2022    05/10/2021
# 148965   A852036       Queen  03/17/2022 05:22:00 PM  Mar 2022    12/08/2021
# 148966   A852775     A852775  05/18/2022 02:13:00 PM  May 2022    01/31/2022
# 148967   A854626     A854626  05/03/2022 04:10:00 PM  May 2022    02/27/2022
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 148963     Adoption             NaN         Cat    Spayed Female
# 148964     Adoption             NaN         Cat    Spayed Female
# 148965     Adoption             NaN         Dog    Spayed Female
# 148966     Adoption          Foster         Cat    Spayed Female
# 148967     Adoption          Foster         Cat    Neutered Male
#
#        Age upon Outcome                     Breed         Color
# ...

# %%
df.shape
# Out:
# (148968, 12)

# %%
data = df.to_dict(orient = "records")

# %%
data
# Out:
# [{'Animal ID': 'A794011',
#   'Name': 'Chunk',
#   'DateTime': '05/08/2019 06:20:00 PM',
#   'MonthYear': 'May 2019',
#   'Date of Birth': '05/02/2017',
#   'Outcome Type': 'Rto-Adopt',
#   'Outcome Subtype': nan,
#   'Animal Type': 'Cat',
#   'Sex upon Outcome': 'Neutered Male',
#   'Age upon Outcome': '2 years',
#   'Breed': 'Domestic Shorthair Mix',
#   'Color': 'Brown Tabby/White'},
#  {'Animal ID': 'A776359',
#   'Name': 'Gizmo',
#   'DateTime': '07/18/2018 04:02:00 PM',
#   'MonthYear': 'Jul 2018',
#   'Date of Birth': '07/12/2017',
#   'Outcome Type': 'Adoption',
#   'Outcome Subtype': nan,
#   'Animal Type': 'Dog',
#   'Sex upon Outcome': 'Neutered Male',
#   'Age upon Outcome': '1 year',
#   'Breed': 'Chihuahua Shorthair Mix',
#   'Color': 'White/Brown'},
#  {'Animal ID': 'A821648',
#   'Name': nan,
#   'DateTime': '08/16/2020 11:38:00 AM',
#   'MonthYear': 'Aug 2020',
#   'Date of Birth': '08/16/2019',
#   'Outcome Type': 'Euthanasia',
#   'Outcome Subtype': nan,
# ...

# %%
db = client["AAC"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'AAC')

# %%
db.animals.insert_many(data)
